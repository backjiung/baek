# %% [markdown]
# <a href="https://colab.research.google.com/github/backjiung/baek/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# TensorFlow and tf.keras
import tensorflow as tf

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.6.0

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# 텐서플로우에서 fashion mnist 데이터셋을 사용하여 바로 사용가능
# Out:
# ...
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# 학습데이터셋의 10개의 카테고리를 별도의 변수로 저장한다.

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()
# 아래의 이미지는 각 픽설값이 0~255까지 저장되어있다.

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0
# 모델을 학습하고 평가하기전 이 값을 최대값 255로 나눠서 범위를 조절한다.

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()
# 훈련세트에서 처음 25개 이미지와 클래스 이름을 출력한다.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])
# 첫번째 레이어에서는 2차원 (28x28)을 입력받고 1차원배열(784)로 변경하는 keras.layers.Flatten 레이어가 사용.
# 파라미터 업데이트 없이 단순히 배열 형태만 변경하는 역할

# 두번째 레이어는 2개의 tf.keras.layers.Dense 레이어.
# 첫번째 Dense 레이어는 128 개의 노드를 갖고, 두번째 레이어는 10개의 Softmax 레이어.
# 세번째 레이어를 통과하게 되면 각각의 카테고리 마다 확률값을 갖는 값이 저장
# 이 값을 모두 합치면 1이되게 됩니다.
# 확률 값이 가장 높은 카테고리가 최종적으로 판단

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
# 모델 학습 전 모델 컴파일에 대한 추가설정 
#Loss function(손실값 측정), optimizer(모델학습),metrics(학습테스트 모니터링)

# %%
model.fit(train_images, train_labels, epochs=10)
#모델에 데이터 입력 2가지 배열로 전달
#test_image사용
# 밑에 수치를 보면 모델 정확도 약 0.89~90(90%)정도
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4943 - accuracy: 0.8262
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3730 - accuracy: 0.8639
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3359 - accuracy: 0.8773
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3115 - accuracy: 0.8869
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2923 - accuracy: 0.8911
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2760 - accuracy: 0.8967
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2655 - accuracy: 0.9010
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2564 - accuracy: 0.9051
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2442 - accuracy: 0.9089
# Epoch 10/10
# ...

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
#모델을 평가할때는 학습에 사용되지않는 테스트 데이터셋으로 평가
#결과는 약 0.89(89%)
# Out:
# 313/313 - 0s - loss: 0.3245 - accuracy: 0.8860
#
# Test accuracy: 0.8859999775886536

# %%
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])

# %%
predictions = probability_model.predict(test_images)

# %%
predictions[0]
#테스트 데이터셋의 첫번째 셋의 예측결과 출력
#각 카테고리별 예측 확률
# Out:
# array([8.0074386e-07, 2.2366012e-11, 3.8948917e-11, 1.4178493e-11,
#        1.9356448e-09, 1.0960634e-04, 3.2407559e-08, 8.0814650e-03,
#        4.0639346e-08, 9.9180812e-01], dtype=float32)

# %%
np.argmax(predictions[0])
#확률이 가장 높은 카테고리 출력
# Out:
# 9

# %%
test_labels[0]
#실제 일치하는지 라벨내용 출력
#결과 일치
# Out:
# 9

# %%
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')
  #10개의 클래스에 대한 예측결과를 모두 그래프출력

# %%
i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()
#신뢰도 만점

# %%
# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], test_labels)
plt.tight_layout()
plt.show()
